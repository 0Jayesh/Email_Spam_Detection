# %%
# !pip install pandas scikit-learn nltk
# Out:
# Collecting pandas
#   Downloading pandas-3.0.2-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp314-cp314-win_amd64.whl.metadata (11 kB)
# Collecting nltk
#   Downloading nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Collecting numpy>=2.3.3 (from pandas)
#   Downloading numpy-2.4.4-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\venv1\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\venv1\Lib\site-packages (from pandas) (2026.2)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp314-cp314-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting click (from nltk)
#   Downloading click-8.3.3-py3-none-any.whl.metadata (2.6 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2026.4.4-cp314-cp314-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: six>=1.5 in .\venv1\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in .\venv1\Lib\site-packages (from click->nltk) (0.4.6)
# Downloading pandas-3.0.2-cp314-cp314-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 773.1 kB/s eta 0:00:13
#    -- ------------------------------------- 0.5/9.9 MB 773.1 kB/s eta 0:00:13
#    --- ------------------------------------ 0.8/9.9 MB 796.7 kB/s eta 0:00:12
#    ---- ----------------------------------- 1.0/9.9 MB 846.7 kB/s eta 0:00:11
#    ----- ---------------------------------- 1.3/9.9 MB 888.0 kB/s eta 0:00:10
#    ------ --------------------------------- 1.6/9.9 MB 924.6 kB/s eta 0:00:09
#    ------- -------------------------------- 1.8/9.9 MB 961.4 kB/s eta 0:00:09
#    -------- ------------------------------- 2.1/9.9 MB 994.3 kB/s eta 0:00:08
#    --------- ------------------------------ 2.4/9.9 MB 1.0 MB/s eta 0:00:08
#    ---------- ----------------------------- 2.6/9.9 MB 1.1 MB/s eta 0:00:07
#    ----------- ---------------------------- 2.9/9.9 MB 1.1 MB/s eta 0:00:07
#    ------------ --------------------------- 3.1/9.9 MB 1.1 MB/s eta 0:00:07
#    ------------- -------------------------- 3.4/9.9 MB 1.1 MB/s eta 0:00:06
#    -------------- ------------------------- 3.7/9.9 MB 1.2 MB/s eta 0:00:06
#    ----------------- ---------------------- 4.2/9.9 MB 1.2 MB/s eta 0:00:05
#    ------------------ --------------------- 4.5/9.9 MB 1.2 MB/s eta 0:00:05
#    -------------------- ------------------- 5.0/9.9 MB 1.3 MB/s eta 0:00:04
#    --------------------- ------------------ 5.2/9.9 MB 1.3 MB/s eta 0:00:04
#    ---------------------- ----------------- 5.5/9.9 MB 1.3 MB/s eta 0:00:04
#    ------------------------ --------------- 6.0/9.9 MB 1.3 MB/s eta 0:00:03
#    -------------------------- ------------- 6.6/9.9 MB 1.4 MB/s eta 0:00:03
#    --------------------------- ------------ 6.8/9.9 MB 1.4 MB/s eta 0:00:03
#    ----------------------------- ---------- 7.3/9.9 MB 1.4 MB/s eta 0:00:02
#    ------------------------------- -------- 7.9/9.9 MB 1.5 MB/s eta 0:00:02
#    -------------------------------- ------- 8.1/9.9 MB 1.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 8.7/9.9 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.9 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 1.6 MB/s  0:00:06
# Downloading scikit_learn-1.8.0-cp314-cp314-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.1 MB 2.5 MB/s eta 0:00:03
#    ------- -------------------------------- 1.6/8.1 MB 2.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.1/8.1 MB 2.6 MB/s eta 0:00:03
#    ------------ --------------------------- 2.6/8.1 MB 2.6 MB/s eta 0:00:03
#    --------------- ------------------------ 3.1/8.1 MB 2.7 MB/s eta 0:00:02
#    ------------------ --------------------- 3.7/8.1 MB 2.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.5/8.1 MB 2.7 MB/s eta 0:00:02
#    ------------------------ --------------- 5.0/8.1 MB 2.8 MB/s eta 0:00:02
#    --------------------------- ------------ 5.5/8.1 MB 2.8 MB/s eta 0:00:01
#    ------------------------------- -------- 6.3/8.1 MB 2.8 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.1 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 2.9 MB/s  0:00:02
# Downloading nltk-3.9.4-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.6 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 4.0 MB/s  0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading numpy-2.4.4-cp314-cp314-win_amd64.whl (12.4 MB)
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.4 MB 4.4 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.8/12.4 MB 4.7 MB/s eta 0:00:03
#    --------- ------------------------------ 2.9/12.4 MB 4.9 MB/s eta 0:00:02
#    ------------ --------------------------- 3.9/12.4 MB 5.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.2/12.4 MB 5.3 MB/s eta 0:00:02
#    --------------------- ------------------ 6.6/12.4 MB 5.4 MB/s eta 0:00:02
#    -------------------------- ------------- 8.1/12.4 MB 5.7 MB/s eta 0:00:01
#    ------------------------------ --------- 9.4/12.4 MB 5.8 MB/s eta 0:00:01
#    -------------------------------- ------- 10.0/12.4 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.7/12.4 MB 5.3 MB/s eta 0:00:01
#    ------------------------------------ --- 11.3/12.4 MB 5.1 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.4 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 4.7 MB/s  0:00:02
# Downloading regex-2026.4.4-cp314-cp314-win_amd64.whl (280 kB)
# Downloading scipy-1.17.1-cp314-cp314-win_amd64.whl (37.3 MB)
#    ---------------------------------------- 0.0/37.3 MB ? eta -:--:--
#     --------------------------------------- 0.5/37.3 MB 3.0 MB/s eta 0:00:13
#    - -------------------------------------- 1.0/37.3 MB 2.9 MB/s eta 0:00:13
#    - -------------------------------------- 1.8/37.3 MB 2.9 MB/s eta 0:00:13
#    -- ------------------------------------- 2.4/37.3 MB 2.9 MB/s eta 0:00:12
#    --- ------------------------------------ 2.9/37.3 MB 3.0 MB/s eta 0:00:12
#    --- ------------------------------------ 3.7/37.3 MB 3.0 MB/s eta 0:00:12
#    ---- ----------------------------------- 4.2/37.3 MB 3.0 MB/s eta 0:00:11
#    ----- ---------------------------------- 5.0/37.3 MB 3.1 MB/s eta 0:00:11
#    ------ --------------------------------- 5.8/37.3 MB 3.1 MB/s eta 0:00:11
#    ------ --------------------------------- 6.3/37.3 MB 3.1 MB/s eta 0:00:10
#    ------- -------------------------------- 7.1/37.3 MB 3.2 MB/s eta 0:00:10
#    -------- ------------------------------- 7.9/37.3 MB 3.2 MB/s eta 0:00:10
#    -------- ------------------------------- 8.4/37.3 MB 3.2 MB/s eta 0:00:09
#    --------- ------------------------------ 9.2/37.3 MB 3.2 MB/s eta 0:00:09
#    ---------- ----------------------------- 10.0/37.3 MB 3.3 MB/s eta 0:00:09
#    ----------- ---------------------------- 10.7/37.3 MB 3.3 MB/s eta 0:00:09
#    ------------ --------------------------- 11.5/37.3 MB 3.3 MB/s eta 0:00:08
#    ------------- -------------------------- 12.3/37.3 MB 3.4 MB/s eta 0:00:08
#    -------------- ------------------------- 13.1/37.3 MB 3.4 MB/s eta 0:00:08
#    -------------- ------------------------- 13.9/37.3 MB 3.4 MB/s eta 0:00:07
#    ---------------- ----------------------- 14.9/37.3 MB 3.5 MB/s eta 0:00:07
#    ---------------- ----------------------- 15.7/37.3 MB 3.5 MB/s eta 0:00:07
#    ----------------- ---------------------- 16.5/37.3 MB 3.5 MB/s eta 0:00:06
#    ------------------ --------------------- 17.3/37.3 MB 3.5 MB/s eta 0:00:06
#    ------------------- -------------------- 18.4/37.3 MB 3.6 MB/s eta 0:00:06
#    -------------------- ------------------- 19.1/37.3 MB 3.6 MB/s eta 0:00:06
#    --------------------- ------------------ 20.2/37.3 MB 3.6 MB/s eta 0:00:05
#    ---------------------- ----------------- 21.0/37.3 MB 3.7 MB/s eta 0:00:05
#    ----------------------- ---------------- 22.0/37.3 MB 3.7 MB/s eta 0:00:05
#    ------------------------ --------------- 22.8/37.3 MB 3.7 MB/s eta 0:00:04
#    ------------------------- -------------- 23.9/37.3 MB 3.8 MB/s eta 0:00:04
#    -------------------------- ------------- 24.9/37.3 MB 3.8 MB/s eta 0:00:04
#    --------------------------- ------------ 26.0/37.3 MB 3.8 MB/s eta 0:00:03
#    ---------------------------- ----------- 26.7/37.3 MB 3.8 MB/s eta 0:00:03
#    ----------------------------- ---------- 27.8/37.3 MB 3.9 MB/s eta 0:00:03
#    ------------------------------ --------- 28.8/37.3 MB 3.9 MB/s eta 0:00:03
#    -------------------------------- ------- 29.9/37.3 MB 3.9 MB/s eta 0:00:02
#    --------------------------------- ------ 30.9/37.3 MB 4.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 32.0/37.3 MB 4.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 33.0/37.3 MB 4.0 MB/s eta 0:00:02
#    ------------------------------------ --- 34.1/37.3 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------- -- 35.4/37.3 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  36.4/37.3 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  37.2/37.3 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 37.3/37.3 MB 4.1 MB/s  0:00:09
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading click-8.3.3-py3-none-any.whl (110 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, threadpoolctl, regex, numpy, joblib, click, scipy, pandas, nltk, scikit-learn
#
#    ----------------------------------------  0/10 [tqdm]
#    ----------------------------------------  0/10 [tqdm]
#    ----------------------------------------  0/10 [tqdm]
#    ----------------------------------------  0/10 [tqdm]
#    ----------------------------------------  0/10 [tqdm]
#    ---- -----------------------------------  1/10 [threadpoolctl]
#    -------- -------------------------------  2/10 [regex]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    -------------------- -------------------  5/10 [click]
#    -------------------- -------------------  5/10 [click]
#    -------------------- -------------------  5/10 [click]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ------------------------ ---------------  6/10 [scipy]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    ---------------------------- -----------  7/10 [pandas]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    -------------------------------- -------  8/10 [nltk]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ------------------------------------ ---  9/10 [scikit-learn]
#    ---------------------------------------- 10/10 [scikit-learn]
#
# Successfully installed click-8.3.3 joblib-1.5.3 nltk-3.9.4 numpy-2.4.4 pandas-3.0.2 regex-2026.4.4 scikit-learn-1.8.0 scipy-1.17.1 threadpoolctl-3.6.0 tqdm-4.67.3
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
import nltk

# Download the stopwords list for filtering common words
nltk.download('stopwords')

# Download the WordNet database used for lemmatization
nltk.download('wordnet')

# Download a helper resource for lemmatization (omw = Open Multilingual Wordnet)
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# True

# %%
NLTK_STOPWORDS = set(stopwords.words('english'))
NLTK_LEMMATIZER = WordNetLemmatizer()

def preprocess_text(text: str) -> str:
    if not isinstance(text, str): return ""
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    words = [NLTK_LEMMATIZER.lemmatize(word)
             for word in text.split()
             if word not in NLTK_STOPWORDS and len(word) > 1]
    return ' '.join(words)

# %%
if __name__ == "__main__":
    print("Starting Spam Detection Training...")

    df = pd.read_csv("spam_data.csv", encoding='latin-1')

    df = df[['sms', 'label']]
    df.dropna(subset=['sms', 'label'], inplace=True)
    df = df[df['sms'].apply(lambda x: isinstance(x, str))]
    df['label'] = pd.to_numeric(df['label'], errors='coerce').astype(int)

    df['processed_sms'] = df['sms'].apply(preprocess_text)

    X = df['processed_sms']
    y = df['label']

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, stratify=y)

    pipeline = Pipeline([
        ('tfidf_vectorizer', TfidfVectorizer(max_features=5000, ngram_range=(1, 1))),
        ('logistic_classifier', LogisticRegression(random_state=42, solver='liblinear', C=1.0, penalty='l2'))
    ])

    pipeline.fit(X_train, y_train)

    predictions = pipeline.predict(X_test)

    print("\nModel Performance:")
    print(f"Accuracy: {accuracy_score(y_test, predictions):.4f}")
    print(f"Precision: {precision_score(y_test, predictions):.4f}")
# Out:
# Starting Spam Detection Training...
#
# Model Performance:
# Accuracy: 0.9699
# Precision: 0.9932
# E:\spam-detection-project\venv1\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
